# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('./global-default-fallback.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray = np.float32(gray)
plt.imshow(gray)

# %%
cv2.goodFeaturesToTrack?

# %%
corners = cv2.goodFeaturesToTrack(gray,maxCorners=30,qualityLevel=0.01,minDistance=10)
corners = np.int64(corners)
print(corners)
# Out:
# [[[718 325]]
#
#  [[180 788]]
#
#  [[123 793]]
#
#  [[766 557]]
#
#  [[266 783]]
#
#  [[238 786]]
#
#  [[323 782]]
#
#  [[778 543]]
#
#  [[209 787]]
#
#  [[766 545]]
#
#  [[295 782]]
#
#  [[773 331]]
#
#  [[805 332]]
#
#  [[651 333]]
#
#  [[749 854]]
#
#  [[151 789]]
#
#  [[822 524]]
#
#  [[ 35 787]]
#
#  [[717 542]]
#
#  [[756 555]]
#
#  [[ 37 799]]
#
#  [[323 769]]
#
#  [[404 776]]
#
#  [[343 788]]
#
#  [[352 769]]
#
#  [[ 67 799]]
#
#  [[285 786]]
#
#  [[224 766]]
#
#  [[755 839]]
#
#  [[ 84 801]]]

# %%
for corner in corners:
    x,y = corner.ravel()
    cv2.circle(img,(x,y),3,255,-1)

# %%
cv2.imwrite('detectedcorners.jpg', img)
# Out:
# True

# %%
plt.imshow(img)
